# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import math

script = pd.read_csv('scripts.csv')

# %%
script["Sentiment"] = 0
columns = list(script)
scriptSentiment = pd.DataFrame(columns=columns)

for index, row in script.iterrows():
    dialogue = row['Dialogue']
    if pd.isnull(dialogue):
        continue
    testimonial = TextBlob(row['Dialogue'])
    row["Sentiment"] = testimonial.sentiment[0]    
    scriptSentiment = scriptSentiment.append(row, ignore_index=True)

    
scriptSentiment.to_csv('scriptSentiment.csv')

# %%
characterColumns = ['Character', 'SEID', 'Sentiment']
characterSentiment = pd.DataFrame(columns=['Character', 'SEID', 'Sentiment'])

for episodeID, episode in scriptSentiment.groupby(['SEID']):
    for characterID, character in episode.groupby(['Character']):
        sentiment = character['Sentiment'].mean()
        thisCharacter = pd.Series([characterID, episodeID, sentiment], index=characterColumns)
        characterSentiment = characterSentiment.append(thisCharacter, ignore_index=True)

characterSentiment.to_csv('characterSentiment.csv')

# %%
import re
def cleanCharacterNames(dialogue):
    return re.sub('\(.*\)', ' ', dialogue)

script['Character'] = script['Character'].apply(cleanCharacterNames)


print (set(script['Character']))
# Out:
# {'ELAINE & RAY', 'TV', 'MR. LIPPMAN', 'NICK', 'Stu', 'IZZY JR.', '(George shows his note-block to Jerry; it says very largely', 'POLICE', 'GEORGE  ', '(Elaine tries to push her alarm clock showing 3', 'KIMBROUGH', 'LOW-TALKER', 'ECHO', 'Woman Behind ELAINE', 'WAITRESS', 'JOE DEVOLA', 'ARONSON', 'HOLLY', 'ELANE', 'HEATHER', 'EVERYBODY', '[CUT TO', 'RONNIE', 'WOMAN AT ANOTHER TABLE', '(A woman rushes in and shouts', 'MAN#3', 'FARKUS', 'VOICE 1  ', '(Kruger leaves and George notices a photograph on the table', '(George looks up and sees Jerry on the other side and frisbee on the other. Jerry says', 'JUDGE  ', "[Jenna's Apartment", 'FATHER', 'MR. GOLDSTEIN', 'Elaine, becoming board', 'MIRANDA', 'WILLIAMS', 'ATTENDANT #2', 'COP', 'BETSY', 'MORGANEWMAN', 'VOGEL', '(The clock reads 5', 'ELECTRICIAN', '[GEORGE', 'Song over the end credits', 'ATTENDANT', 'PRISONER 2', 'CHARLES', 'MORGAN', 'RESTON  ', 'JAMES', "JERRY'S MACHINE", 'INTERPRETER', 'RADIO', 'LINDSAY', 'JERRY\x92S OUTGOING MESSAGE', 'BUILDING C', '(Through the phone', 'VIOLIN PLAYER', 'MRS. CHOATE', 'MR. GRAHAM', 'DONNA', 'WELLS', 'MANNY', 'MR. CROSS', 'MABEL', 'STEVE', 'ROBERT', 'Announcer', 'ADA', 'JERY', 'DANIELLE', '*Note', 'PAUL - Locker room Attendant #1', 'Huckleberry', '[Movie Theater', 'BANK EMPLOYEE', '[Alex Theatre', 'SUSAN AND ALLSION', 'MORTY', 'ALL FOUR MEN', 'PETERMAN  ', 'VET', 'BOBBY', 'HANKE', "ELAINE'S VOICE", 'FELDMAN', 'OLD MAN #3', 'MONTAGE', 'MARCELLINO', 'BUILDING A', 'SHARON', 'BARRY', 'SUNNY', 'RAQUEL', 'RHISA', 'STORE MANAGER', 'NEIGHBOR', 'TEDDY', 'SALES WOMAN', "JOE'S WIFE", 'JEANINE', 'BIKER', 'MAURA', 'POSTMAN', 'LADY 1', 'TARA', 'MELANIE', 'PLAYER  ', 'Frank  ', 'Sari / Saree', '[The Intervention [NOTE', 'STREET TOUGH', 'RECEPTIONIST', 'Man', 'LETTERMAN', "JERRY'S brain", 'MAID', 'ANNOUNCEMENT', 'FRANK  ', 'UMPIRE', '(She turns the radio on loud (Foghat', 'ANNOUNCER #1', 'MARION', 'RIVERA', 'CHOATE', 'JERRY AND JOEL', 'TONY', 'HAL', 'PHIL', 'ANNOUNCER', 'ICE CREAM VENDER #1', 'ROBBER', "[Back at Jerry's apartment", 'HELENA', 'PAT HAZELL', 'MAN 2', 'AENT', '"SALMAN"', 'DWAYNE', 'LAMAR', 'SASHA', '(Movie Voice', 'OLD WOMAN  ', 'DENIM VEST', '(ELAINE decides to make herself at home, opens the refrigerator and starts eating olives out of a jar, with her fingers. In the living room area, KEVIN is looking at her. Note', 'ABBY', 'BRADY', 'ROBERTA', 'WOMAN #1', 'SALLY', 'ALL THREE', 'CYNTHIA', 'RABBI', 'GARDNER', 'FOWLER', 'DOORMAN 2', 'OLDER MAN', "% The movie has sold out. ``Real good, George. Real good.'' It's now 10", 'JOHN', 'WORKER  ', 'STEFANIE', 'GINO', '[ACT ONE SCENE A INT. ESCALATOR - GOING DOWN TO A GARAGE. IN SINGLE FILE', 'MAN IN THE CROWD', 'JAY', 'BRUCE  ', "(Fade to the next morning, the alarm clock goes off, it's 5", 'Another man', 'DOORMAN', 'Opening scene', 'PEGGY', 'RESTON', 'PHILBIN', 'WYCK', 'FEMALE WORKER', 'FRIEND', 'DUNCAN & JERRY', 'TIA', 'Hx', "MONK'S MANAGER", '% From his pocket, Kramer digs into his treasured Papaya King hot dog. Then discovers the source of his discomfort', 'MAN #1 ', 'DR. COOPERMAN', 'ZUBIN', 'RUSTY', 'LISI', 'JERRY & KRAMER', 'INTERVIEWER', 'FRANK', '(Another car passes', 'MRS ALLISTER  ', '% Apparently, a movie that can be interpreted on two levels. Misunderstanding number two', 'TINA', 'STEVEN', 'KERI', 'HOOKER', 'RAY', 'MRS. ZANFINO', 'HIGH PITCHED VOICE', 'VIC', 'MODEL #1', 'AGENCY REP', 'BOOKMAN  ', 'ELLEN', 'MEMBER 1', 'MRS ALLISTER', 'Newscaster', 'MAN', 'HOLE DIGGER', 'HOMELESS MAN 2', 'Tina', 'REMY', 'KURT  ', 'http', 'WENDY', '[setting', '(At the same time--DONNA', 'BOOKMAN', 'DUNCAN', 'LYLE', 'KELLY', 'RUDY', 'JERRY and ELAINE, together', 'MRS. ENRIGHT', 'MILOS', 'MAHJONG LADY', 'GUILLERMO', 'MACHINE', 'DANA  ', 'STUDENT #2', 'SKYCAP', 'EGO', '[Witness', 'JERRY AND NEWMAN', 'WIFE', 'RAMON', 'TUTTLE', 'CLAIE', 'BLAINE', 'CONTEST WINNER  ', 'PETE', 'ELAINE', "(The two have that uncomfortable politeness that only comes about when you're down to the last piece of pizza. Jerry breaks the silence", ...

# %%
def listToFreqDict(allList):
    thisFreqDF = pd.DataFrame(columns=['Word', 'Frequency'])
    uniqueList = list(set(allList))
    uniqueList = [word for word in uniqueList if word not in exclude]
    for word in uniqueList:
        thisFreq = pd.Series([word, allList.count(word)], index=['Word', 'Frequency'])
        thisFreqDF = thisFreqDF.append(thisFreq, ignore_index=True)
    return thisFreqDF

exclude = ['and', 'if', 'had', 'didnt', 'there','got', 'im', "i'd", "doesn't", 'do', 'else', 'be', 'it', 'its', 'she', 'her', 'hers', 'he', 'his', 'you', 'them','yours', 'theirs', 'did', 'i', 'dont', 'not', 'had', 'has', 'could', 'couldnt']
freqColumns = ['Character', 'Word', 'Frequency']
freqDF = pd.DataFrame(columns=freqColumns)

# for episodeID, episode in script.groupby(['SEID']):
for characterID, character in script.groupby(['Character']):
    print (characterID)
    allList = []
    for index, row in character.iterrows():
        dialogue = row['Dialogue'] 
        if pd.isnull(dialogue):
            continue
        dialogue = re.sub('[!@#$.(),?*""]', ' ', dialogue)
        allList += dialogue.split().lower()          
        
    thisFreqDF = listToFreqDict(allList)
    thisFreqDF["Character"] = characterID
    freqDF = freqDF.append(thisFreqDF)

        
freqDF.to_csv('word_frequencies_character.csv')
# Out:
#
#   KRUGER
#   accompanies assorted shots of working-man Kramer
#   to figuring out what is going on here, when the "question fatale" is asked
# "SALMAN"
# "SALMAN"
# % A night at the Improv. Jerry receives some disturbing news from the manager
# % Apparently, a movie that can be interpreted on two levels. Misunderstanding number two
# % From his pocket, Kramer digs into his treasured Papaya King hot dog. Then discovers the source of his discomfort
# % In the background is the plot complication of the week
# % Misunderstanding number one
# % The movie has sold out. ``Real good, George. Real good.'' It's now 10
# (** Footnote
# (*Farina
# (4
# (A moment later, the clock flips to 5
# (A woman rushes in and shouts
# (Another car passes
# (At the same time--DONNA
# (Camera shot at the clock on his wall. The clock says 9
# (ELAINE decides to make herself at home, opens the refrigerator and starts eating olives out of a jar, with her fingers. In the living room area, KEVIN is looking at her. Note
# (ELAINE finally notices them, but suddenly from the other direction, three other guys are coming
# (Elaine and Ed are in bed. Elaine awakes to find out that it's 9
# (Elaine is robbed of her peek into the first class section by a drawn curtain and she goes to her seat. However, someone comes after her and
# (Elaine peels out and turns on the car stereo. She hears
# (Elaine tries to push her alarm clock showing 3
# (Fade to the next morning, the alarm clock goes off, it's 5
# (George looks up and sees Jerry on the other side and frisbee on the other. Jerry says
# (George shows his note-block to Jerry; it says very largely
# (George takes a hold of Jerry's leg to stress the point and Sharon, who obviously thinks she has a real story here now, asks another question
# (Helen turns to Jerry and makes a face like
# (IMG SRC=http
# (Jerry and TV Elaine
# (Jerry gets to his seat, however, he also is in the wrong seat
# (Jerry wakes up with the sunlight. Looks at the electric clock, which stopped at 4
# (Jerry's doing his stand-up routine at a comedy club. There's the music theme and we don't hear what he is saying, but the closed captions put that
# (Kramer rolls over to go to sleep. The bedside clock reads 12
# (Kruger leaves and George notices a photograph on the table
# (Movie Voice
# (Newman goes to the back room with the muffin stumps and sets down a cooler and an empty glass. From the cooler he takes out 4 bottles of milk and sets them down. He bites into a stump, then takes a drink of milk from the glass. (continuity error
# (Not that that approach was going to work, or anything, but what minute chance they had of convincing her is blown away as the door bursts open and
# (Scene
# (She turns the radio on loud (Foghat
# (The clock reads 3
# (The clock reads 5
# (The episode opens with a series of clips from 'The Pitch', 'The Ticket' and 'TheWallet', illustrating the story so far. A rough precis would be
# (The race is on and Pappanick is slowly making ground. Kramer is pounding himself imitating the jockey and shouts
# (The show begins. There are three different settings while the show is on TV. Each line or description will be preceded by the right setting
# (The two have that uncomfortable politeness that only comes about when you're down to the last piece of pizza. Jerry breaks the silence
# (They start to "sing", growing more excited after each iteration
# (Through the phone
# (Two clocks at a table, both 4
# (We see Kramer, groaning and holding his stomach, running down the hall, and opening the bathroom's door. Someone in there says
# (You can make out the albums pretty clearly. One is an apparent K-Tel "classic"
# (a few minutes later, the ceremony is about to begin. Someone in the crowd yells
# (again, from the movie we hear this dialogue
# (from the movie we hear this dialogue
# (knock on door
# (meanwhile Kramer is climbing over the dugout retrieve George's cap... the camera cuts to the field where the batter hits a pop fly to where Kramer is
# (once again, from the movie we hear this dialogue
# ** Pies - Just in case you did not know what these two kinds of pies are
# *Note
# 2nd MOVIE PATRON
# <IMG SRC=http
# AARON
# AARON & HELEN
# ABBY
# ADA
# ADAM
# ADE
# AENT
# AGENCY REP
# AGENT
# AL
# AL ROKER
# ALAN
# ALEC
# ALEX
# ALEX TREBEK
# ALICIA
# ALISON
# ALL
# ALL
# ALL FOUR MEN
# ALL THREE
# ALLBRIGHT
# ALLISON
# ALLSION
# ALTON
# AMANDA
# AMY
# ANGELA
# ANGRY MAN
# ANNA
# ANNOUNCEMENT
# ANNOUNCER
# ANNOUNCER #1
# ANNOUNCER #2
# ANNOUNCER ON P.A. SYSTEM
# ANNOUNCER ON TV
# ANSWERING MACHINE
# ANTONIO
# APPLICANT
# ARNIE
# ARONSON
# ARTIE
# ASSISTANT
# ASSISTANT DRESSER
# ATTENDANT
# ATTENDANT #1
# ATTENDANT #2
# AUCTIONEER
# AUDIENCE
# AUDREY
# AUNT MAY
# AVA
# Announcer
# Another man
# BABS
# BABU
# BABU'S BROTHER
# BABU'S FRIEND
# BAILIFF
# BANIA
# BANK EMPLOYEE
# BARBARA
# BARNEY'S SALES ASSOCIATE
# BARRY
# BARTENDER
# BECK
# BECKY
# BEN
# BENES
# BETH
# BETSY
# BETSY
# BETTE
# BIKER
# BILL
# BILLY
# BLAINE
# BLIND MAN
# BLIND VIOLIN PLAYER
# BOB
# BOBBY
# BOMB COP
# BONNIE
# BOOKIE
# BOOKMAN
# BOOKMAN
# BOSS
# BOSS' WIFE
# BOTH
# BOUNCER
# BOY
# BOYFRIEND
# BRADY
# BRETT
# BRIDGET
# BRODY
# BRUCE
# BRUCE
# BRYANT
# BUBBLE BOY
# BUCKLES
# BUDDY
# BUILDING A
# BUILDING B
# BUILDING C
# BUSINESS MAN
# BUSINESSMAN
# VOICE 1
# VOICE 2
# VOICE FROM POKER GAME
# VOICE ON INTERCOM
# VOICE ON SPEAKER
# VOICE ON THE PHONE
# VOIGHT
# Voice
# WAITER
# WAITRESS
# WAITRESS
# WAITRESS #1
# WAITRESS #2
# WALKER #1
# WALKER #2
# WALKER #3
# WALTER
# WATKINS
# WELLS
# WENDY
# WENDY
# WEST
# WHATLEY
# WIFE
# WILCOX
# WILHELM
# WILKIE
# WILLIAMS
# WILLIE
# WILLIE SR
# WILTON
# WINONA
# WINONA
# WOMAN
# WOMAN #1
# WOMAN #2
# WOMAN 1
# WOMAN 2
# WOMAN AT ANOTHER TABLE
# WOMAN AT BEACH
# WOMAN AT NEXT TABLE
# WOMAN AT PHONE
# WOMAN AT YET ANOTHER TABLE
# WOMAN IN THE CROWD
# WOMAN'S VOICE ON THE PHONE
# WOMANEWMAN
# WORKER
# WORKER
# WORKERS
# WYCK
# We gotta go! It's 8
# We see the title 'Jerry', then, sitting at the comedy club, we see
# Woman Behind ELAINE
# Women
# Women
# Wx
# YELLING GUY
# YOUNG COP
# ZACH
# ZEKE
# ZUBIN
# [5A. Kramer and Newman are making sausages. Tape recorder plays Jackie Davis
# [ACT ONE SCENE A INT. ESCALATOR - GOING DOWN TO A GARAGE. IN SINGLE FILE
# [Alex Theatre
# [As they struggle to force the Junior Mint on each other, Jerry pushes Kramers' hand away and -- in slow motion with the sound of a beating heart to emphasize the event -- The Junior Mint is launched into the air towards the operating table and, well, in a word
# [At JERRY
# [At the entrance of the church. There is a sign there. It reads
# [At the restaurant! GEORGE
# [Back at Jerry's apartment
# [Background cars
# [CUT TO
# [Elaine is on the phone and the radio plays music very loud (Iron Butterfly
# [Elaine is still waiting to get into the bathroom-- there's someone in there. *Finally*, a ZZ Top reject comes out of the bathroom and, to paraphrase Jerry in "The Smelly Car"
# [Exterior long shot
# [GEORGE
# [George's Car
# [Jenna's Apartment
# [Jerry's apartment, Jerry and Elaine. Jerry is looking Dream cafe with binoculars. There's a sign on the window
# [Leaving the Gentle Touch Car Wash
# [Limo driving on the street -- then inside the limo
# [Movie Theater
# [New Witness
# [On the bright side, Kramer and George arrive at the airport. They're running to the terminal
# [Opening Scene
# [Outside Kramers apartment door
# [Poppie's Restaurant
# [STOCK FOOTAGE
# [Scene
# [Setting
# [Street
# [Street Outside Alex
# [Subway train
# [The Bodega, starts with a shot of Marcelino's cash register with Jerry's clown check attached under a sign that reads "checks no longer accepted from
# [The Intervention [NOTE
# [Witness
# [Yankee Stadium
# [location
# [monk's
# [setting
# http
# so far

# %%
freqDF[freqDF['Character'] == 'JERRY'].to_csv('word_frequencies_jerry.csv')
freqDF[freqDF['Character'] == 'GEORGE'].to_csv('word_frequencies_george.csv')
freqDF[freqDF['Character'] == 'ELAINE'].to_csv('word_frequencies_elaine.csv')
freqDF[freqDF['Character'] == 'KRAMER'].to_csv('word_frequencies_kramer.csv')

main = ['JERRY', 'GEORGE', 'ELAINE', 'KRAMER']
freqDF[freqDF['Character'].isin(main) ].to_csv('word_frequencies_main.csv')
